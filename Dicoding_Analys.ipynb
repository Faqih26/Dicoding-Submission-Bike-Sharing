# %% [markdown]
# # Proyek Analisis Data: Nama dataset
# - Nama: Faqih Suryana
# - Email: faqihsuryana148@gmail.com
# - Id Dicoding:faqih_suryana_NURk

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Perbandingan pengguna di hari libur dan tidak dalam penggunaan sepeda dan jam berapa saja yang menyebabkan banyaknya pengguna
# - Season apa saja yang memiliki banyak pengguna sepeda

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_data = pd.read_csv("https://raw.githubusercontent.com/Faqih26/dicoding/main/Bike-sharing-dataset/day.csv")
day_data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_data = pd.read_csv("https://raw.githubusercontent.com/Faqih26/dicoding/main/Bike-sharing-dataset/hour.csv")
hour_data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# semua kolom dan datatype pada dataset day_data sudah benar kecuali dteday

# %%
day_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_data.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# tidak terdapat duplikasi pada dataset day_data

# %%
day_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# tidak ditemukan hal yang tidak sesuai dengan statistik yang ditampilkan berdasarkan day_data

# %%
day_data.describe().T
# Out:
#             count         mean          std        min          25%  \
# instant     731.0   366.000000   211.165812   1.000000   183.500000
# season      731.0     2.496580     1.110807   1.000000     2.000000
# yr          731.0     0.500684     0.500342   0.000000     0.000000
# mnth        731.0     6.519836     3.451913   1.000000     4.000000
# holiday     731.0     0.028728     0.167155   0.000000     0.000000
# weekday     731.0     2.997264     2.004787   0.000000     1.000000
# workingday  731.0     0.683995     0.465233   0.000000     0.000000
# weathersit  731.0     1.395349     0.544894   1.000000     1.000000
# temp        731.0     0.495385     0.183051   0.059130     0.337083
# atemp       731.0     0.474354     0.162961   0.079070     0.337842
# hum         731.0     0.627894     0.142429   0.000000     0.520000
# windspeed   731.0     0.190486     0.077498   0.022392     0.134950
# casual      731.0   848.176471   686.622488   2.000000   315.500000
# registered  731.0  3656.172367  1560.256377  20.000000  2497.000000
# cnt         731.0  4504.348837  1937.211452  22.000000  3152.000000
#
#                     50%          75%          max
# instant      366.000000   548.500000   731.000000
# season         3.000000     3.000000     4.000000
# yr             1.000000     1.000000     1.000000
# mnth           7.000000    10.000000    12.000000
# holiday        0.000000     0.000000     1.000000
# weekday        3.000000     5.000000     6.000000
# workingday     1.000000     1.000000     1.000000
# weathersit     1.000000     2.000000     3.000000
# temp           0.498333     0.655417     0.861667
# atemp          0.486733     0.608602     0.840896
# hum            0.626667     0.730209     0.972500
# windspeed      0.180975     0.233214     0.507463
# casual       713.000000  1096.000000  3410.000000
# registered  3662.000000  4776.500000  6946.000000
# cnt         4548.000000  5956.000000  8714.000000

# %% [markdown]
# semua kolom dan datatype pada dataset hour_data sudah benar kecuali dteday

# %%
hour_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_data.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# tidak terdapat duplikasi pada dataset hour_data

# %%
hour_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# tidak ditemukan hal yang tidak sesuai dengan statistik yang ditampilkan berdasarkan hour_data

# %%
hour_data.describe().T
# Out:
#               count         mean          std   min        25%        50%  \
# instant     17379.0  8690.000000  5017.029500  1.00  4345.5000  8690.0000
# season      17379.0     2.501640     1.106918  1.00     2.0000     3.0000
# yr          17379.0     0.502561     0.500008  0.00     0.0000     1.0000
# mnth        17379.0     6.537775     3.438776  1.00     4.0000     7.0000
# hr          17379.0    11.546752     6.914405  0.00     6.0000    12.0000
# holiday     17379.0     0.028770     0.167165  0.00     0.0000     0.0000
# weekday     17379.0     3.003683     2.005771  0.00     1.0000     3.0000
# workingday  17379.0     0.682721     0.465431  0.00     0.0000     1.0000
# weathersit  17379.0     1.425283     0.639357  1.00     1.0000     1.0000
# temp        17379.0     0.496987     0.192556  0.02     0.3400     0.5000
# atemp       17379.0     0.475775     0.171850  0.00     0.3333     0.4848
# hum         17379.0     0.627229     0.192930  0.00     0.4800     0.6300
# windspeed   17379.0     0.190098     0.122340  0.00     0.1045     0.1940
# casual      17379.0    35.676218    49.305030  0.00     4.0000    17.0000
# registered  17379.0   153.786869   151.357286  0.00    34.0000   115.0000
# cnt         17379.0   189.463088   181.387599  1.00    40.0000   142.0000
#
#                    75%         max
# instant     13034.5000  17379.0000
# season          3.0000      4.0000
# yr              1.0000      1.0000
# mnth           10.0000     12.0000
# hr             18.0000     23.0000
# holiday         0.0000      1.0000
# weekday         5.0000      6.0000
# workingday      1.0000      1.0000
# weathersit      2.0000      4.0000
# temp            0.6600      1.0000
# atemp           0.6212      1.0000
# hum             0.7800      1.0000
# windspeed       0.2537      0.8507
# casual         48.0000    367.0000
# registered    220.0000    886.0000
# cnt           281.0000    977.0000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Memperbaiki type data pada kedua dataset pada kolom dteday yang sebelumnya object menjadi datetime

# %%
day_data["dteday"] = pd.to_datetime(day_data["dteday"])
hour_data["dteday"] = pd.to_datetime(hour_data["dteday"])

# %% [markdown]
# mengecek kembali tipe data yang sudah diperbaiki

# %%
day_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
hour_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# mengubah data pada dataset day_data pada kolom season dimana
#
#
#  1 = Musim Semi
#  2 = Musim Panas
#  3 = Musim Gugur
#  4 = Musim Salju

# %%
day_data.loc[day_data["season"] == 1, "season"] = "Semi"
day_data.loc[day_data["season"] == 2, "season"] = "Panas"
day_data.loc[day_data["season"] == 3, "season"] = "Gugur"
day_data.loc[day_data["season"] == 4, "season"] = "Salju"

day_data.season.value_counts()
# Out:
# Gugur    188
# Panas    184
# Semi     181
# Salju    178
# Name: season, dtype: int64

# %%
hour_data.loc[hour_data["season"] == 1, "season"] = "Spring"
hour_data.loc[hour_data["season"] == 2, "season"] = "Summer"
hour_data.loc[hour_data["season"] == 3, "season"] = "Fall"
hour_data.loc[hour_data["season"] == 4, "season"] = "Winter"


hour_data.season.value_counts()
# Out:
# Fall      4496
# Summer    4409
# Spring    4242
# Winter    4232
# Name: season, dtype: int64

# %% [markdown]
# mengubah isi data pada dataset day_data dan hour_data pada kolom yr dimana
#
#
#  0 = 2011
#  1 = 2012

# %%
hour_data.loc[hour_data["yr"] == 0, "yr"] = 2011
hour_data.loc[hour_data["yr"] == 1, "yr"] = 2012
day_data.loc[day_data["yr"] == 0, "yr"] = 2011
day_data.loc[day_data["yr"] == 1, "yr"] = 2012

print("day Dataset")
day_data.yr.value_counts()
print("hour Dataset")
hour_data.yr.value_counts()
# Out:
# day Dataset
# hour Dataset
# 2012    8734
# 2011    8645
# Name: yr, dtype: int64

# %%
day_data.loc[day_data["holiday"] == 0, "holiday"] = "Holiday"
day_data.loc[day_data["holiday"] == 1, "holiday"] = "Not a Holiday"
hour_data.loc[hour_data["holiday"] == 0, "holiday"] = "Holiday"
hour_data.loc[hour_data["holiday"] == 1, "holiday"] = "Not a Holiday"

print("day Dataset")
day_data.holiday.value_counts().sort_index()
# Out:
# day Dataset
# Holiday          710
# Not a Holiday     21
# Name: holiday, dtype: int64

# %%
print("hour Dataset")
hour_data.holiday.value_counts().sort_index()
# Out:
# hour Dataset
# Holiday          16879
# Not a Holiday      500
# Name: holiday, dtype: int64

# %%
weekday_names = {0: "Sun", 1: "Mon", 2: "Tue", 3: "Wed", 4: "Thu", 5: "Fri", 6: "Sat"}

day_data["weekday"] = day_data["weekday"].replace(weekday_names)
hour_data["weekday"] = hour_data["weekday"].replace(weekday_names)

day_data.weekday.value_counts().sort_index()
# Out:
# Fri    104
# Mon    105
# Sat    105
# Sun    105
# Thu    104
# Tue    104
# Wed    104
# Name: weekday, dtype: int64

# %%
hour_data.weekday.value_counts().sort_index()
# Out:
# Fri    2487
# Mon    2479
# Sat    2512
# Sun    2502
# Thu    2471
# Tue    2453
# Wed    2475
# Name: weekday, dtype: int64

# %%
def get_time_of_day(hour):
    # check the hour value and return the corresponding time of day
    if hour < 6:
        return "Night"
    elif hour < 12:
        return "Morning"
    elif hour < 18:
        return "Afternoon"
    else:
        return "Evening"

# %%
hour_data['time_of_day'] = hour_data['hr'].apply(get_time_of_day)
hour_data.time_of_day.value_counts()
# Out:
# Afternoon    4375
# Evening      4368
# Morning      4360
# Night        4276
# Name: time_of_day, dtype: int64

# %%
day_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    object
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    object
#  6   weekday     731 non-null    object
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(3)
# memory usage: 91.5+ KB

# %%
hour_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instant      17379 non-null  int64
#  1   dteday       17379 non-null  datetime64[ns]
#  2   season       17379 non-null  object
#  3   yr           17379 non-null  int64
#  4   mnth         17379 non-null  int64
#  5   hr           17379 non-null  int64
#  6   holiday      17379 non-null  object
#  7   weekday      17379 non-null  object
#  8   workingday   17379 non-null  int64
#  9   weathersit   17379 non-null  int64
#  10  temp         17379 non-null  float64
#  11  atemp        17379 non-null  float64
#  12  hum          17379 non-null  float64
#  13  windspeed    17379 non-null  float64
#  14  casual       17379 non-null  int64
#  15  registered   17379 non-null  int64
#  16  cnt          17379 non-null  int64
#  17  time_of_day  17379 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(9), object(4)
# memory usage: 2.4+ MB

# %%
weathername = {1: "Clear", 2: "Mist + Cloudy", 3: "Light Snow", 4: "Heavy Rain"}

day_data["weathersit"] = day_data["weathersit"].replace(weathername)
hour_data["weathersit"] = hour_data["weathersit"].replace(weathername)

day_data.weathersit.value_counts().sort_index()
# Out:
# Clear            463
# Light Snow        21
# Mist + Cloudy    247
# Name: weathersit, dtype: int64

# %%
hour_data.weathersit.value_counts().sort_index()
# Out:
# Clear            11413
# Heavy Rain           3
# Light Snow        1419
# Mist + Cloudy     4544
# Name: weathersit, dtype: int64

# %% [markdown]
# pengubahan data dilakukan untuk memudahkan pemahaman akan data

# %%
day_data.groupby(by='mnth').agg({
    'cnt': ['max', 'min', 'mean', 'sum']
})
# Out:
#        cnt
#        max   min         mean     sum
# mnth
# 1     4521   431  2176.338710  134933
# 2     5062  1005  2655.298246  151352
# 3     8362   605  3692.258065  228920
# 4     7460   795  4484.900000  269094
# 5     8294  2633  5349.774194  331686
# 6     8120  3767  5772.366667  346342
# 7     8173  3285  5563.677419  344948
# 8     7865  1115  5664.419355  351194
# 9     8714  1842  5766.516667  345991
# 10    8156    22  5199.225806  322352
# 11    6852  1495  4247.183333  254831
# 12    6606   441  3403.806452  211036

# %%
day_data.corr()
# Out:
# <ipython-input-29-b39b893bcbbd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   day_data.corr()
#              instant        yr      mnth  workingday      temp     atemp  \
# instant     1.000000  0.866025  0.496702   -0.004337  0.150580  0.152638
# yr          0.866025  1.000000 -0.001792   -0.002013  0.047604  0.046106
# mnth        0.496702 -0.001792  1.000000   -0.005901  0.220205  0.227459
# workingday -0.004337 -0.002013 -0.005901    1.000000  0.052660  0.052182
# temp        0.150580  0.047604  0.220205    0.052660  1.000000  0.991702
# atemp       0.152638  0.046106  0.227459    0.052182  0.991702  1.000000
# hum         0.016375 -0.110651  0.222204    0.024327  0.126963  0.139988
# windspeed  -0.112620 -0.011817 -0.207502   -0.018796 -0.157944 -0.183643
# casual      0.275255  0.248546  0.123006   -0.518044  0.543285  0.543864
# registered  0.659623  0.594248  0.293488    0.303907  0.540012  0.544192
# cnt         0.628830  0.566710  0.279977    0.061156  0.627494  0.631066
#
#                  hum  windspeed    casual  registered       cnt
# instant     0.016375  -0.112620  0.275255    0.659623  0.628830
# yr         -0.110651  -0.011817  0.248546    0.594248  0.566710
# mnth        0.222204  -0.207502  0.123006    0.293488  0.279977
# workingday  0.024327  -0.018796 -0.518044    0.303907  0.061156
# temp        0.126963  -0.157944  0.543285    0.540012  0.627494
# atemp       0.139988  -0.183643  0.543864    0.544192  0.631066
# hum         1.000000  -0.248489 -0.077008   -0.091089 -0.100659
# windspeed  -0.248489   1.000000 -0.167613   -0.217449 -0.234545
# casual     -0.077008  -0.167613  1.000000    0.395282  0.672804
# registered -0.091089  -0.217449  0.395282    1.000000  0.945517
# cnt        -0.100659  -0.234545  0.672804    0.945517  1.000000

# %%
corr = day_data.select_dtypes('number').corr()

# %%
cmap = sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .format(precision=3)\
    .set_properties(**{'max-width': '1000px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_table_styles(magnify())
# Out:
# <style type="text/css">
# #T_4315d th {
#   font-size: 7pt;
# }
# #T_4315d td {
#   padding: 0em 0em;
# }
# #T_4315d th:hover {
#   font-size: 12pt;
# }
# #T_4315d tr:hover td:hover {
#   max-width: 200px;
#   font-size: 12pt;
# }
# #T_4315d_row0_col0, #T_4315d_row1_col1, #T_4315d_row2_col2, #T_4315d_row3_col3, #T_4315d_row4_col4, #T_4315d_row5_col5, #T_4315d_row6_col6, #T_4315d_row7_col7, #T_4315d_row8_col8, #T_4315d_row9_col9, #T_4315d_row10_col10 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row0_col1, #T_4315d_row1_col0 {
#   background-color: #6d95c8;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row0_col2 {
#   background-color: #e0e6ed;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row0_col3 {
#   background-color: #dc5e77;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row0_col4 {
#   background-color: #e491a1;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row0_col5, #T_4315d_row10_col3 {
#   background-color: #e492a3;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row0_col6 {
#   background-color: #dd657d;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row0_col7, #T_4315d_row1_col6, #T_4315d_row2_col7, #T_4315d_row3_col8, #T_4315d_row4_col7, #T_4315d_row5_col7, #T_4315d_row6_col7, #T_4315d_row7_col6, #T_4315d_row8_col3, #T_4315d_row9_col7, #T_4315d_row10_col7 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row0_col8 {
#   background-color: #eabbc4;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row0_col9 {
#   background-color: #aec3dd;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row0_col10, #T_4315d_row9_col1 {
#   background-color: #b8c9e0;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row1_col2, #T_4315d_row1_col3 {
#   background-color: #dd5f78;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row1_col4, #T_4315d_row1_col5 {
#   background-color: #df6f85;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row1_col7 {
#   background-color: #dc5b75;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row1_col8 {
#   background-color: #e9b1bc;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row1_col9 {
#   background-color: #c3d1e4;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row1_col10 {
#   background-color: #cbd7e6;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row2_col0 {
#   background-color: #d4dde9;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row2_col1 {
#   background-color: #e0798d;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row2_col3 {
#   background-color: #e0778c;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row2_col4 {
#   background-color: #eabcc5;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row2_col5 {
#   background-color: #ebbfc8;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row2_col6, #T_4315d_row3_col6 {
#   background-color: #ebbec6;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row2_col8 {
#   background-color: #e6a0ae;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row2_col9, #T_4315d_row10_col2 {
#   background-color: #eed3d8;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row2_col10 {
#   background-color: #edcfd5;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row3_col0, #T_4315d_row3_col2 {
#   background-color: #eab7c1;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row3_col1 {
#   background-color: #eab8c2;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row3_col4, #T_4315d_row3_col5, #T_4315d_row6_col2 {
#   background-color: #ecc5cc;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row3_col7 {
#   background-color: #e9b4be;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row3_col9 {
#   background-color: #e3e8ee;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row3_col10 {
#   background-color: #ecc6ce;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row4_col0 {
#   background-color: #e69dab;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row4_col1 {
#   background-color: #e17c90;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row4_col2 {
#   background-color: #e9b2bd;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row4_col3 {
#   background-color: #e17d91;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row4_col5, #T_4315d_row5_col4 {
#   background-color: #457abb;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row4_col6 {
#   background-color: #e494a4;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row4_col8 {
#   background-color: #ccd8e7;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row4_col9, #T_4315d_row8_col9 {
#   background-color: #cdd9e7;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row4_col10 {
#   background-color: #b4c7df;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row5_col0 {
#   background-color: #e7a3b0;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row5_col1 {
#   background-color: #e28194;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row5_col2 {
#   background-color: #eab9c3;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row5_col3 {
#   background-color: #e28497;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row5_col6 {
#   background-color: #e69ead;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row5_col8, #T_4315d_row5_col9 {
#   background-color: #c9d6e6;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row5_col10 {
#   background-color: #b0c4dd;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row6_col0 {
#   background-color: #e3889a;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row6_col1 {
#   background-color: #dd637c;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row6_col3 {
#   background-color: #e38a9c;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row6_col4 {
#   background-color: #e7a8b5;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row6_col5 {
#   background-color: #e8adb8;
#   color: #000000;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row6_col8 {
#   background-color: #df6d84;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row6_col9 {
#   background-color: #de6980;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row6_col10 {
#   background-color: #de667e;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row7_col0, #T_4315d_row10_col6 {
#   background-color: #dd627b;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row7_col1 {
#   background-color: #e18093;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row7_col2 {
#   background-color: #d94764;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row7_col3 {
#   background-color: #e17e92;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row7_col4 {
#   background-color: #db5570;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row7_col5 {
#   background-color: #da4e6a;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row7_col8 {
#   background-color: #db526e;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row7_col9 {
#   background-color: #d84462;
#   color: #f1f1f1;
#   max-width: 1000px;
#   font-size: 10pt;
# }
# #T_4315d_row7_col10 {
#   background-color: #d83e5d;
#   color: #f

# %%
day_data.to_csv("cleandataday.csv", index=False)

# %%
hour_data.to_csv("cleanhourdata.csv", index=False)

# %% [markdown]
# ### Explore Hour_data

# %%
hour_data['time_of_day'].value_counts()
# Out:
# Afternoon    4375
# Evening      4368
# Morning      4360
# Night        4276
# Name: time_of_day, dtype: int64

# %%
hour_data['hr'].value_counts().sort_index()
# Out:
# 0     726
# 1     724
# 2     715
# 3     697
# 4     697
# 5     717
# 6     725
# 7     727
# 8     727
# 9     727
# 10    727
# 11    727
# 12    728
# 13    729
# 14    729
# 15    729
# 16    730
# 17    730
# 18    728
# 19    728
# 20    728
# 21    728
# 22    728
# 23    728
# Name: hr, dtype: int64

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# bandingkan pengguna di hari libur dan tidak dalam penggunaan sepeda dan jam berapa saja

# %%
holiday_day_data = day_data.groupby(by="holiday").instant.nunique().reset_index()
holiday_day_data.rename(columns={
    "instant": "sum"
}, inplace=True)
holiday_day_data
# Out:
#          holiday  sum
# 0        Holiday  710
# 1  Not a Holiday   21

# %%
holiday_hour_data = hour_data.groupby(by="holiday").instant.nunique().reset_index()
holiday_hour_data.rename(columns={
    "instant": "sum"
}, inplace=True)
holiday_hour_data
# Out:
#          holiday    sum
# 0        Holiday  16879
# 1  Not a Holiday    500

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    y="sum",
    x="holiday",
    data=holiday_day_data.sort_values(by="holiday", ascending=False),
)
plt.title("Number Bike by hari kerja", loc="center", fontsize=15)
plt.ylabel("Jumlah Pemakai")
plt.xlabel("Hari Kerja")
plt.tick_params(axis="x", labelsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    y="sum",
    x="holiday",
    data=holiday_hour_data.sort_values(by="holiday", ascending=False),
)
plt.title("Number Bike by hari kerja", loc="center", fontsize=15)
plt.ylabel("Jumlah Pemakai")
plt.xlabel("Hari Kerja")
plt.tick_params(axis="x", labelsize=12)
plt.show()

# %% [markdown]
# Berdasarkan hal diatas ditemuka bahwa hari libur merupakan hari dimana banyak pengguna menggunakan sepeda

# %%
day_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    object
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    object
#  6   weekday     731 non-null    object
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    object
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(7), object(4)
# memory usage: 91.5+ KB

# %%
holiday_hour  = hour_data[hour_data['holiday']=='Holiday']

# %%
holiday_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16879 entries, 0 to 17378
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instant      16879 non-null  int64
#  1   dteday       16879 non-null  datetime64[ns]
#  2   season       16879 non-null  object
#  3   yr           16879 non-null  int64
#  4   mnth         16879 non-null  int64
#  5   hr           16879 non-null  int64
#  6   holiday      16879 non-null  object
#  7   weekday      16879 non-null  object
#  8   workingday   16879 non-null  int64
#  9   weathersit   16879 non-null  object
#  10  temp         16879 non-null  float64
#  11  atemp        16879 non-null  float64
#  12  hum          16879 non-null  float64
#  13  windspeed    16879 non-null  float64
#  14  casual       16879 non-null  int64
#  15  registered   16879 non-null  int64
#  16  cnt          16879 non-null  int64
#  17  time_of_day  16879 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(8), object(5)
# memory usage: 2.4+ MB

# %%
holiday_hour.head()
# Out:
#    instant     dteday  season    yr  mnth  hr  holiday weekday  workingday  \
# 0        1 2011-01-01  Spring  2011     1   0  Holiday     Sat           0
# 1        2 2011-01-01  Spring  2011     1   1  Holiday     Sat           0
# 2        3 2011-01-01  Spring  2011     1   2  Holiday     Sat           0
# 3        4 2011-01-01  Spring  2011     1   3  Holiday     Sat           0
# 4        5 2011-01-01  Spring  2011     1   4  Holiday     Sat           0
#
#   weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0      Clear  0.24  0.2879  0.81        0.0       3          13   16
# 1      Clear  0.22  0.2727  0.80        0.0       8          32   40
# 2      Clear  0.22  0.2727  0.80        0.0       5          27   32
# 3      Clear  0.24  0.2879  0.75        0.0       3          10   13
# 4      Clear  0.24  0.2879  0.75        0.0       0           1    1
#
#   time_of_day
# 0       Night
# 1       Night
# 2       Night
# 3       Night
# 4       Night

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    y="cnt",
    x="hr",
    data=holiday_hour.sort_values(by="hr", ascending=False),
)
plt.title("Number of Bike Sharing by Hour", loc="center", fontsize=15)
plt.ylabel("Jumlah Pengguna")
plt.xlabel("Hour")
plt.tick_params(axis="x", labelsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    y="cnt",
    x="time_of_day",
    data=holiday_hour.sort_values(by="time_of_day", ascending=False),
)
plt.title("Number of Bike Sharing by time_of_day", loc="center", fontsize=15)
plt.ylabel("Jumlah Pengguna")
plt.xlabel("Time Of Day")
plt.tick_params(axis="x", labelsize=12)
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# Season apa saja yang memiliki banyak pengguna sepeda

# %%
season_data = day_data.groupby(by="season").instant.nunique().reset_index()
season_data.rename(columns={
    "instant": "sum"
}, inplace=True)
season_data
# Out:
#   season  sum
# 0  Gugur  188
# 1  Panas  184
# 2  Salju  178
# 3   Semi  181

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    y="sum",
    x="season",
    data=season_data.sort_values(by="season", ascending=False),
)
plt.title("Number of Bike Sharing by Season", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis="x", labelsize=12)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Berdasarkan hasil pengamatan pada Pertanyaan 1 ditemukan bahwa hari libur merupakan hari dimana sepeda banyak digunakan
#
# *   Berdasarkan holiday_hour ditemukan bahwa pengguna paling banyak ditemukan pada jam malam pada waktu 17 sampai dengan 19

# %% [markdown]
# Berdasarkan hasil pengamatan pada pertanyaan 2 bahwa tidak ada permasalahan pada tiap season untuk para pengguna

# %% [markdown]
# ### Korelasi Antar Kolom

# %% [markdown]
# *   Kolom temp dan atemp memiliki korelasi yang sangat tinggi (0.991702), yang berarti bahwa mereka hampir sama dalam mengukur suhu udara. Ini masuk akal karena temp adalah suhu aktual dan atemp adalah suhu yang dirasakan oleh pengguna.
#
#
#
# *   Kolom casual dan workingday memiliki korelasi yang sangat rendah (-0.518044), yang berarti bahwa mereka memiliki hubungan negatif yang cukup kuat. Ini berarti bahwa permintaan sepeda dari pengguna kasual cenderung lebih rendah pada hari kerja dan lebih tinggi pada akhir pekan atau hari libur.
# *   Kolom registered dan cnt memiliki korelasi yang sangat tinggi (0.945517), yang berarti bahwa mereka memiliki hubungan positif yang sangat kuat. Ini berarti bahwa permintaan sepeda secara keseluruhan didominasi oleh pengguna terdaftar, yang lebih stabil dan dapat diprediksi daripada pengguna kasual.
#
# *   Kolom windspeed dan hum memiliki korelasi yang rendah dengan kolom lainnya, yang berarti bahwa mereka tidak terlalu mempengaruhi permintaan sepeda. Namun, mereka memiliki korelasi negatif dengan kolom cnt, yang berarti bahwa permintaan sepeda cenderung menurun ketika kecepatan angin atau kelembaban meningkat.
